# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, c='red', ls='dashdot', lw="10", label='Y values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.2 Adding another plot

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, c='red', label='Y values')
plt.plot(x, y_2, label="Y2 values")
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
import numpy as np
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, c='red', label='Y values')
plt.errorbar(x, y_1, xerr=y_2)
plt.plot(x, y_2, label="Y2 values")
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %%
import numpy as np
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, c='#5b4a12', label='Y values')
plt.errorbar(x, y_1, c='#000000', xerr=x)
plt.plot(x, y_2, label="Y2 values")
plt.errorbar(x, y_2, xerr=x)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y',c="red")
plt.grid(alpha=1, c="#345677", ls="dashdot")
plt.legend(loc="lower right")
plt.show()

#1. Colour also accepts hexcodes
#2. alpha channel modifies transparency
#3. Yes. Just specify the colour parameter.
#4. Ok.
#5. Ok. Default is upper right. Upper / lower, left / right

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(0,6.28,0.01)
y = np.sin(x.copy())

plt.plot(x, y, c="coral")
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
# Your code here

# %% [markdown]
# ### 1.7 We need another axis!

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0,6,30)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dotted', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### 1.8 Saving to disc

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0,6,30)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dotted', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.savefig("simple-plot.png",dpi=150)
plt.show()

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5, color="#692439")
plt.title("Daily Average Land Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature Difference")
plt.style.use("fivethirtyeight")
plt.show()
'''plt.hlines(0, date[0], date[-1], linestyle="dashdot", colors='grey')
plt.ylim([-4, 4])
plt.show()'''
# Out:
# 'plt.hlines(0, date[0], date[-1], linestyle="dashdot", colors=\'grey\')\nplt.ylim([-4, 4])\nplt.show()'

# %% [markdown]
# ### 2.2 xkcd!

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5, color="#692439")
plt.hlines(0, date[0], date[-1], linestyle="dashdot", colors='grey')
plt.title("Daily Average Land Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature Difference")
#plt.xkcd()
plt.show()
'''
plt.ylim([-4, 4])
plt.show()'''
# Out:
# '\nplt.ylim([-4, 4])\nplt.show()'

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
from matplotlib import pyplot as plt
import numpy as np

# Some data for plotting
x = np.arange(0,6)
y = x.copy() * 4
x_err = 0.25
y_err = x.copy() * 0.5

plt.plot(x, y)
plt.style.use("default")
plt.errorbar(x, y, xerr=x_err, yerr=y_err,
             color="darkred", linestyle="dashed",
             marker="o", markerfacecolor="yellow",
             ecolor="black",capsize=5,
             label="Y values with errors")
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc="lower right")
plt.show(block=False)

# %% [markdown]
# ## Exercise 2 :  A simple mathematical plot

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0, 50, 200)
ex = np.e ** (-1 * x.copy() / 10)
sinx = np.sin(x.copy())
y = ex * sinx
plt.plot(x, y)
plt.grid(alpha=0.25)
plt.xlabel("X")
plt.ylabel("Y",rotation=0)
plt.title("$y = e^{-x/10} sin(x)$")
plt.ylim(-1, 1)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0, 50, 200)
ex = np.e ** (-1 * x.copy() / 10)
sinx = np.sin(x.copy())
y = ex * sinx
plt.plot(x, y)
plt.grid(alpha=0.25)
plt.xlabel("x", fontsize=15, color="darkblue")
plt.ylabel("y", rotation=0, fontsize=15, color="darkblue")
plt.title("$y = e^{-x/10} sin(x)$", fontsize=20)
plt.ylim(-1, 1)
plt.show()
